# %%
import pandas as pd

# %%
# %ls old
# Out:
# res0xp0.csv      res14xp0fct.csv  res20xp0.csv     res4xp0.csv
# res0xp1.csv      res15xp0src.csv  res27xp0src.csv  res5xp0.csv
# res0xp2.csv      res16xp0fct.csv  res28xp0.csv     res6xp0.csv
# res10xp0fct.csv  res17xp0fct.csv  res29xp0obj.csv  res7xp0.csv
# res11xp0src.csv  res18xp0.csv     res2xp0.csv      res8xp0src.csv
# res12xp0obj.csv  res19xp0.csv     res2xp1.csv      res9xp0obj.csv
# res13xp0.csv     res1xp0.csv      res3xp0.csv

# %%
name = "res9xp0obj.csv"
csv = pd.read_csv("old/"+name, sep=";")
csv = csv.drop(["NORMA"], axis=1)
intv = f"INTERVAL:{csv['INTERVAL'].iloc[0]}"
csv['INTERVAL'] = ""
csv = csv.rename(columns={'INTERVAL':intv})
csv.to_csv(name, sep=";", columns=csv.columns, index=False)

# %%
csv
# Out:
#      TYPEG  NB_OBJ  NB_SRC  NB_FL  NB_FU  NBF  TRUST  \
# 0     ncpr       5      10      4      4   20     40
# 1     ncpr       5      10      4      4   20     42
# 2     ncpr       5      10      4      4   20     42
# 3     ncpr       5      10      4      4   20     40
# 4     ncpr       5      10      4      4   20     40
# ...    ...     ...     ...    ...    ...  ...    ...
# 1995  ncpr       5      10      4      4   20     48
# 1996  ncpr       5      10      4      4   20     46
# 1997  ncpr       5      10      4      4   20     48
# 1998  ncpr       5      10      4      4   20     46
# 1999  ncpr       5      10      4      4   20     46
#
#                                                      SF  \
# 0     9,19-5,17-2,5,10,17-13,17-5,9,15,17-11,13-2,16...
# 1     3,8,15-0,7,9,12,17-5,9-0,5,14-4-3,5,14,16-1,5,...
# 2     1,10,13-2,7,11,14,19-0,6,17-6,16-3-3,7,9,12,16...
# 3     9,18-2,5,12,18-4,8,15,19-1,4,18-12,18-2,4,10-3...
# ...
